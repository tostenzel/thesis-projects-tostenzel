# %%
import sys
# Define relative path.
sys.path.append("..")

# %%
import pandas as pd
import matplotlib.pyplot as plt

from scrypy.figures_py.plots import distplot
from scrypy.figures_py.figure_cone_plot_choice_shares import cone_plot_choice_shares
from scrypy.figures_py.plots import convergence_plot

# %%
# Cell only for travis to execute for a small number of iterations saved in the results directory
# Import the stored results.
qoi_mean_params_change_mean_edu = pd.read_pickle("../scrypy/results/qoi_mean_params_change_mean_edu_df.pkl")
qoi_mean_params_base_occ_shares = pd.read_pickle("../scrypy/results/qoi_mean_params_base_occ_shares_df.pkl")
qoi_mean_params_policy_occ_shares = pd.read_pickle("../scrypy/results/qoi_mean_params_policy_occ_shares_df.pkl")

mc_base_occ_shares = pd.read_pickle("../scrypy/results/mc_base_occ_shares_df.pkl")
mc_policy_occ_shares = pd.read_pickle("../scrypy/results/mc_policy_occ_shares_df.pkl")
mc_change_mean_edu = pd.read_pickle("../scrypy/results/mc_change_mean_edu_df.pkl")
mc_input_parameters = pd.read_pickle("../scrypy/results/mc_input_parameters_df.pkl")

cone_plot_choice_shares()

plt.style.use('../scrypy/_mplstyle/uq.mplstyle') # wanna include that in funciton.

distplot(mc_change_mean_edu.values.T, r"$\Delta$ in mean years of education", save=True)
convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_mean_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=False, save=True
    )

convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_mean_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=True, save=True
    )

# %%
# Import the stored results.
qoi_mean_params_change_mean_edu = pd.read_pickle("../scrypy/results/10_000_draws/qoi_mean_params_change_mean_edu_df.pkl")
qoi_mean_params_base_occ_shares = pd.read_pickle("../scrypy/results/10_000_draws/qoi_mean_params_base_occ_shares_df.pkl")
qoi_mean_params_policy_occ_shares = pd.read_pickle("../scrypy/results/10_000_draws/qoi_mean_params_policy_occ_shares_df.pkl")

mc_base_occ_shares = pd.read_pickle("../scrypy/results/10_000_draws/mc_base_occ_shares_df.pkl")
mc_policy_occ_shares = pd.read_pickle("../scrypy/results/10_000_draws/mc_policy_occ_shares_df.pkl")
mc_change_mean_edu = pd.read_pickle("../scrypy/results/10_000_draws/mc_change_mean_edu_df.pkl")
mc_input_parameters = pd.read_pickle("../scrypy/results/10_000_draws/mc_input_parameters_df.pkl")

# %%
cone_plot_choice_shares()
# Out:
# (<Figure size 720x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D6E8FD518>,
# ...
#        dtype=object))

# %%
plt.style.use('../scrypy/_mplstyle/uq.mplstyle') # wanna include that in funciton.
distplot(mc_change_mean_edu.values.T, r"Change in mean years of education", save=True)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x22d6cca41d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x22d6cca41d0>)

# %%
# Attention: I changed index title from avg to mean!!! Will be active if new data is generated.
convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_avg_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=False, save=True
    )
# Out:
# (<module 'matplotlib.pyplot' from 'C:\\Users\\Tobias\\AppData\\Local\\conda\\conda\\envs\\uq\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2934ceafe10>)

# %%
# Attention: I changed index title from avg to mean!!! Will be active if new data is generated.
convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_avg_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=True, save=True
    )
# Out:
# (<module 'matplotlib.pyplot' from 'C:\\Users\\Tobias\\AppData\\Local\\conda\\conda\\envs\\uq\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2934e024d68>)
