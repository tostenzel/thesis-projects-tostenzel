# %%
import pandas as pd
import matplotlib.pyplot as plt

from python.multi_quantities_of_interest import model_wrapper_kw_94
from python.script_uncertainty_propagation import propagate_mean_estimates
from python.plots import distplot
from python.plots import convergence_plot

# %%
_, _, _= propagate_mean_estimates(save=True)

# %%
#propagate_mean_estimates(save=True)

# %%
qoi_mean_params_change_mean_edu = pd.read_pickle("python/results/qoi_mean_params_edu_df.pkl")
qoi_mean_params_base_occ_shares = pd.read_pickle("python/results/qoi_mean_params_base_occ_shares_df.pkl")
qoi_mean_params_policy_occ_shares = pd.read_pickle("python/results/qoi_mean_params_policy_occ_shares_df.pkl")

# %%
mc_base_occ_shares = pd.read_pickle("python/results/mc_base_occ_shares_df.pkl")
mc_policy_occ_shares = pd.read_pickle("python/results/mc_policy_occ_shares_df.pkl")
mc_change_avg_edu = pd.read_pickle("python/results/mc_change_avg_edu_df.pkl")
mc_input_parameters = pd.read_pickle("python/results/mc_input_parameters_df.pkl")

# %%
mc_base_occ_shares
# Out:
# Choice   home    edu      a      b
# Age
# 16      0.020  0.439  0.442  0.099
# 17      0.049  0.285  0.476  0.190
# 18      0.039  0.240  0.493  0.228
# 19      0.040  0.227  0.475  0.258
# 20      0.041  0.200  0.474  0.285
# 21      0.023  0.172  0.469  0.336
# 22      0.018  0.165  0.460  0.357
# 23      0.021  0.151  0.422  0.406
# 24      0.022  0.135  0.417  0.426
# 25      0.021  0.103  0.418  0.458
# 26      0.015  0.075  0.422  0.488
# 27      0.016  0.071  0.387  0.526
# 28      0.020  0.064  0.392  0.524
# 29      0.009  0.052  0.382  0.557
# 30      0.019  0.053  0.351  0.577
# 31      0.011  0.041  0.363  0.585
# 32      0.011  0.042  0.353  0.594
# 33      0.011  0.028  0.341  0.620
# 34      0.008  0.020  0.329  0.643
# 35      0.019  0.014  0.324  0.643
# 36      0.017  0.004  0.324  0.655
# 37      0.016  0.008  0.314  0.662
# 38      0.007  0.006  0.329  0.658
# 39      0.015  0.004  0.312  0.669
# 40      0.011  0.000  0.317  0.672
# 41      0.017  0.001  0.317  0.665
# 42      0.009  0.001  0.308  0.682
# 43      0.016  0.000  0.316  0.668
# 44      0.012  0.000  0.313  0.675
# 45      0.014  0.000  0.296  0.690
# ..        ...    ...    ...    ...
# 26      0.016  0.072  0.429  0.483
# 27      0.016  0.067  0.394  0.523
# 28      0.021  0.063  0.397  0.519
# 29      0.011  0.044  0.387  0.558
# 30      0.018  0.044  0.364  0.574
# 31      0.011  0.034  0.372  0.583
# 32      0.012  0.034  0.361  0.593
# 33      0.012  0.023  0.355  0.610
# 34      0.007  0.019  0.337  0.637
# 35      0.018  0.010  0.328  0.644
# 36      0.017  0.005  0.325  0.653
# 37      0.015  0.009  0.321  0.655
# 38      0.008  0.006  0.331  0.655
# 39      0.014  0.003  0.315  0.668
# 40      0.010  0.000  0.315  0.675
# 41      0.016  0.000  0.319  0.665
# 42      0.009  0.001  0.307  0.683
# 43      0.019  0.000  0.313  0.668
# 44      0.007  0.000  0.318  0.675
# 45      0.013  0.000  0.298  0.689
# 46      0.016  0.000  0.294  0.690
# 47      0.012  0.000  0.314  0.674
# 48      0.020  0.000  0.295  0.685
# 49      0.012  0.000  0.292  0.696
# 50      0.014  0.000  0.292  0.694
# 51      0.017  0.000  0.287  0.696
# 52      0.020  0.000  0.286  0.694
# 53      0.017  0.000  0.288  0.695
# 54      0.013  0.000  0.290  0.697
# 55      0.018  0.000  0.287  0.695
#
# [4000 rows x 4 columns]

# %%
plt.style.use('python/uq.mplstyle') # wanna include that in funciton.
distplot(mc_change_avg_edu.values.T, r"$\Delta$ in mean years of education", save=True)

# %%
import numpy as np
np.mean(qoi_mc)

# %%
convergence_plot(qoi_mc["avg_schooling"], qoi_base["avg_schooling"][0], "QoI", absolute_deviation=False, save=True)

# %%
convergence_plot(qoi_mc["avg_schooling"], qoi_base["avg_schooling"][0], "QoI", absolute_deviation=True, save=True)
