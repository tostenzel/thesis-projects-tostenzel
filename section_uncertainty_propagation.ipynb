# %%
import pandas as pd
import matplotlib.pyplot as plt

from python.plots import distplot
from python.plots import convergence_plot

# %%
qoi_mean_params_change_mean_edu = pd.read_pickle("python/results/qoi_mean_params_edu.pkl")
qoi_mean_params_base_shares = pd.read_pickle("python/results/qoi_mean_params_base_shares.pkl")
qoi_mean_params_policy_shares = pd.read_pickle("python/results/qoi_mean_params_policy_shares.pkl")

# %%
mc_base_shares = pd.read_pickle("python/results/mc_base_shares_df.pkl")
mc_policy_shares = pd.read_pickle("python/results/mc_policy_shares_df.pkl")
mc_change_avg_edu = pd.read_pickle("python/results/mc_change_avg_edu_df.pkl")
mc_input_parameters = pd.read_pickle("python/results/mc_input_parameters_df.pkl")

# %%
mc_change_avg_edu
# Out:
#                         0      1      2      3      4      5      6      7    \
# change_avg_schooling  1.597  1.427  1.362  1.364  1.571  1.552  1.438  1.675
#
#                         8      9    ...    190    191    192    193   194  \
# change_avg_schooling  1.412  1.452  ...  1.487  1.482  1.572  1.329  1.48
#
#                         195    196  197    198    199
# change_avg_schooling  1.485  1.591  1.5  1.593  1.495
#
# [1 rows x 200 columns]

# %%
plt.style.use('python/uq.mplstyle') # wanna include that in funciton.
distplot(mc_change_avg_edu.values, r"$\Delta$ in mean years of education", save=True)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1bb55d7cef0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1bb55d7cef0>)

# %%
import numpy as np
np.mean(qoi_mc)

# %%
convergence_plot(qoi_mc["avg_schooling"], qoi_base["avg_schooling"][0], "QoI", absolute_deviation=False, save=True)

# %%
convergence_plot(qoi_mc["avg_schooling"], qoi_base["avg_schooling"][0], "QoI", absolute_deviation=True, save=True)
