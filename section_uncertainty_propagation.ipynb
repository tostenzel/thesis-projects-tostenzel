# %%
import pandas as pd
import matplotlib.pyplot as plt

from python.plots import distplot
from python.figure_cone_plot_choice_shares import cone_plot_choice_shares
from python.plots import convergence_plot

# %%
# Compute the QoI with mean input parameters and evaluated at a randomly draws sample of input parameters given the estimates for the input distribution.

# Run from command line. Only a call from there works due to the applied parallelisation library.
#python script_uncertainty_propagation.py

# %%
# Import the stored results.
qoi_mean_params_change_mean_edu = pd.read_pickle("python/results/qoi_mean_params_change_mean_edu_df.pkl")
qoi_mean_params_base_occ_shares = pd.read_pickle("python/results/qoi_mean_params_base_occ_shares_df.pkl")
qoi_mean_params_policy_occ_shares = pd.read_pickle("python/results/qoi_mean_params_policy_occ_shares_df.pkl")

mc_base_occ_shares = pd.read_pickle("python/results/mc_base_occ_shares_df.pkl")
mc_policy_occ_shares = pd.read_pickle("python/results/mc_policy_occ_shares_df.pkl")
mc_change_mean_edu = pd.read_pickle("python/results/mc_change_mean_edu_df.pkl")
mc_input_parameters = pd.read_pickle("python/results/mc_input_parameters_df.pkl")

# %%
cone_plot_choice_shares()
# Out:
# (<Figure size 720x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B0BFAED5F8>,
# ...
#        dtype=object))

# %%
plt.style.use('python/uq.mplstyle') # wanna include that in funciton.
# add pdf line to legend.
distplot(mc_change_mean_edu.values.T, r"$\Delta$ in mean years of education", save=True)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1b0c0d0f978>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b0c0d0f978>)

# %%
# Attention: I changed index title from avg to mean!!! Will be active if new data is generated.
from python.plots import convergence_plot
convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_avg_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=False, save=True
    )
# Out:
# (<module 'matplotlib.pyplot' from 'C:\\Users\\Tobias\\AppData\\Local\\conda\\conda\\envs\\uq\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b0bfd57c50>)

# %%
# Attention: I changed index title from avg to mean!!! Will be active if new data is generated.
convergence_plot(
    mc_change_mean_edu.values.T, qoi_mean_params_change_mean_edu["change_avg_schooling"][0],
    r"$\Delta$ in mean years of education",
    absolute_deviation=True, save=True
    )
# Out:
# (<module 'matplotlib.pyplot' from 'C:\\Users\\Tobias\\AppData\\Local\\conda\\conda\\envs\\uq\\lib\\site-packages\\matplotlib\\pyplot.py'>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b0c2019748>)
